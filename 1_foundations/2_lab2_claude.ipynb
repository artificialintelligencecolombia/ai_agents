# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY2')
model_name = "claude-opus-4-6"

# %%
messages = [{"role": "user", "content": "How to extend life?"}]

# %%
claude = Anthropic()
response = claude.messages.create(
    model=model_name, 
    messages=messages,
    timeout=30,
    max_tokens=1024,
    system="You are an AI assistant. Be a robot, analyze the request, come with a concise, clear, and accurate answer. If you don't know the answer, say 'I don't know'."
    )
answer = response.content[0].text
print(answer)
# Out:
# # How to Extend Life
#
# Based on current scientific evidence, here are the most well-supported strategies:
#
# ## Lifestyle
#
# - **Exercise regularly** – Both aerobic and strength training (150+ min/week moderate activity)
# - **Maintain a healthy weight** – Avoid obesity and being severely underweight
# - **Don't smoke** – Single biggest avoidable risk factor
# - **Limit alcohol** – Moderate or no consumption
# - **Sleep 7–9 hours** consistently
#
# ## Diet
#
# - **Eat mostly whole foods** – Vegetables, fruits, whole grains, legumes, nuts
# - **Reduce ultra-processed foods** and added sugars
# - **Consider Mediterranean or Blue Zone-style diets**
# - **Avoid overeating** – Caloric moderation (some evidence for mild caloric restriction)
#
# ## Mental & Social Health
#
# - **Maintain strong social connections** – Loneliness is a major mortality risk
# - **Manage stress** – Meditation, mindfulness, therapy
# - **Stay mentally engaged** – Lifelong learning, purpose, and meaning
#
# ...
